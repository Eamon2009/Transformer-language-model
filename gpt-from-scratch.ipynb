# %% [markdown]
# # Dataset Loading
#
# - Load the raw training text file
#
# - Read the entire dataset into memory
#
# - Inspect dataset size and preview content

# %%
with open("traindata.txt",'r',encoding='utf-8') as f:
       text=f.read()

# %%
print("The length of Data set:",len(text))
# Out:
# The length of Data set: 48151

# %%
print(text[:1000])
# Out:
# The Portrait of a Lady
# A Photograph
# “We’re Not Afraid to Die... if We
# Can All Be Together”
# Discovering Tut: the Saga
# Continues
# The Laburnum Top
# The Voice of the Rain
# The Ailing Planet: the Green
# Movement’s Role
# Childhood
# The Adventure
# Silk Road
# Father to Son
# Reprint 2025-26
# Effective reading is receiving from others
# their ideas and feelings.
# Effective reading involves
#  understanding the text
#  talking about the text
#  thinking about language
#  working with words
#  noticing form and patterns.
# Reprint 2025-26
# 1. The Portrait of a Lady
# Khushwant Singh
# Notice these expressions in the text.
# Infer their meaning from the context.
# My grandmother, like everybody’s grandmother, was an old woman.
# She had been old and wrinkled for the twenty years that I had known
# her. People said that she had once been young and pretty and had
# even had a husband, but that was hard to believe. My grandfather’s
# portrait hung above the mantelpiece in the drawing room. He wore a
# big turban and loose-fitting clothes.

# %%
chars=list(set(text))
vocab_size=len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
# M824tH?,—:qBmIrhSY)’xGyF3vJP
# (Lb c5sD6O1U_.K!jXfl–A”R-9w;…EZaenzdik‘7W0/u“N*CpTgoV
# 84

# %% [markdown]
# # Clean the Dataset
#
# -Remove punctuation, digits, and symbols
#
# # Keep only:
#
# - alphabets
# - spaces
# - newline
# - Convert text to lowercase

# %%
import re

with open("traindata.txt", "r", encoding="utf-8") as f:
    text = f.read()

# keep alphabets, spaces, and newline
text = re.sub(r"[^A-Za-z\s\n]", " ", text)

# clean extra spaces but keep line structure
text = re.sub(r"[ ]+", " ", text)

# convert to lowercase
text = text.lower()

with open("cleaned.txt", "w", encoding="utf-8") as f:
    f.write(text)

print("cleaning complete")
# Out:
# cleaning complete

# %% [markdown]
# # Load Cleaned Dataset
#
# `` Load the processed dataset ``
# ```Check size and preview text ```

# %%
with open("cleaned.txt",'r',encoding='utf-8') as f:
       text2=f.read()

# %%
print(f"Lenght of the data set:{len(text2)} ")
# Out:
# Lenght of the data set:46532

# %% [markdown]
# - First 1000 characters

# %%
print(text2[:1000])
# Out:
# the portrait of a lady
# a photograph
#  we re not afraid to die if we
# can all be together
# discovering tut the saga
# continues
# the laburnum top
# the voice of the rain
# the ailing planet the green
# movement s role
# childhood
# the adventure
# silk road
# father to son
# reprint
# effective reading is receiving from others
# their ideas and feelings
# effective reading involves
#  understanding the text
#  talking about the text
#  thinking about language
#  working with words
#  noticing form and patterns
# reprint
#  the portrait of a lady
# khushwant singh
# notice these expressions in the text
# infer their meaning from the context
# my grandmother like everybody s grandmother was an old woman
# she had been old and wrinkled for the twenty years that i had known
# her people said that she had once been young and pretty and had
# even had a husband but that was hard to believe my grandfather s
# portrait hung above the mantelpiece in the drawing room he wore a
# big turban and loose fitting clothes his long white beard covered the

# %% [markdown]
# ## Build Character Vocabulary
#
# - Extract unique characters from dataset
# - Compute vocabulary size
# - chars → unique characters
# - vocab_size → number of tokens in dataset

# %%
chars2=sorted(list(set(text2)))
vocab_size2=len(chars2)
print(''.join(chars2))
print(vocab_size2)
# Out:
#  abcdefghijklmnopqrstuvwxyz
# 28

# %% [markdown]
# ## Encode and Decode Functions
#  - Encode text → token IDs
#  - Decode token IDs → text

# %%
stri = {ch:i for i, ch in enumerate(chars2)}
it = {i:ch for i, ch in enumerate(chars2)}

encode = lambda s: [stri[c] for c in s]# a function that take a string triverse it and return a integer list
decode = lambda l: ''.join([it[i] for i in l])# a function that convert the 

print(encode("eamon"))
print(decode(encode("eamon")))
# Out:
# [6, 2, 14, 16, 15]
# eamon

# %% [markdown]
# ## Convert Dataset to Tensor
# - Convert encoded tokens to PyTorch tensor

# %%
import torch
data=torch.tensor(encode(text2),dtype=torch.long)
print(data.dtype,data.shape)
# Out:
# torch.int64 torch.Size([46532])

# %%
print(data[:1000])
# Out:
# tensor([21,  9,  6,  1, 17, 16, 19, 21, 19,  2, 10, 21,  1, 16,  7,  1,  2,  1,
#         13,  2,  5, 26,  0,  2,  1, 17,  9, 16, 21, 16,  8, 19,  2, 17,  9,  0,
#          1, 24,  6,  1, 19,  6,  1, 15, 16, 21,  1,  2,  7, 19,  2, 10,  5,  1,
#         21, 16,  1,  5, 10,  6,  1, 10,  7,  1, 24,  6,  0,  4,  2, 15,  1,  2,
#         13, 13,  1,  3,  6,  1, 21, 16,  8,  6, 21,  9,  6, 19,  1,  0,  5, 10,
#         20,  4, 16, 23,  6, 19, 10, 15,  8,  1, 21, 22, 21,  1, 21,  9,  6,  1,
#         20,  2,  8,  2,  0,  4, 16, 15, 21, 10, 15, 22,  6, 20,  0, 21,  9,  6,
#          1, 13,  2,  3, 22, 19, 15, 22, 14,  1, 21, 16, 17,  0, 21,  9,  6,  1,
#         23, 16, 10,  4,  6,  1, 16,  7,  1, 21,  9,  6,  1, 19,  2, 10, 15,  0,
#         21,  9,  6,  1,  2, 10, 13, 10, 15,  8,  1, 17, 13,  2, 15,  6, 21,  1,
#         21,  9,  6,  1,  8, 19,  6,  6, 15,  0, 14, 16, 23,  6, 14,  6, 15, 21,
#          1, 20,  1, 19, 16, 13,  6,  0,  4,  9, 10, 13,  5,  9, 16, 16,  5,  0,
#         21,  9,  6,  1,  2,  5, 23,  6, 15, 21, 22, 19,  6,  0, 20, 10, 13, 12,
#          1, 19, 16,  2,  5,  0,  7,  2, 21,  9,  6, 19,  1, 21, 16,  1, 20, 16,
#         15,  0, 19,  6, 17, 19, 10, 15, 21,  1,  0,  6,  7,  7,  6,  4, 21, 10,
#         23,  6,  1, 19,  6,  2,  5, 10, 15,  8,  1, 10, 20,  1, 19,  6,  4,  6,
#         10, 23, 10, 15,  8,  1,  7, 19, 16, 14,  1, 16, 21,  9,  6, 19, 20,  0,
#         21,  9,  6, 10, 19,  1, 10,  5,  6,  2, 20,  1,  2, 15,  5,  1,  7,  6,
#          6, 13, 10, 15,  8, 20,  1,  0,  6,  7,  7,  6,  4, 21, 10, 23,  6,  1,
#         19,  6,  2,  5, 10, 15,  8,  1, 10, 15, 23, 16, 13, 23,  6, 20,  0,  1,
#         22, 15,  5,  6, 19, 20, 21,  2, 15,  5, 10, 15,  8,  1, 21,  9,  6,  1,
#         21,  6, 25, 21,  0,  1, 21,  2, 13, 12, 10, 15,  8,  1,  2,  3, 16, 22,
#         21,  1, 21,  9,  6,  1, 21,  6, 25, 21,  0,  1, 21,  9, 10, 15, 12, 10,
#         15,  8,  1,  2,  3, 16, 22, 21,  1, 13,  2, 15,  8, 22,  2,  8,  6,  0,
#          1, 24, 16, 19, 12, 10, 15,  8,  1, 24, 10, 21,  9,  1, 24, 16, 19,  5,
#         20,  0,  1, 15, 16, 21, 10,  4, 10, 15,  8,  1,  7, 16, 19, 14,  1,  2,
#         15,  5,  1, 17,  2, 21, 21,  6, 19, 15, 20,  1,  0, 19,  6, 17, 19, 10,
#         15, 21,  1,  0,  1, 21,  9,  6,  1, 17, 16, 19, 21, 19,  2, 10, 21,  1,
#         16,  7,  1,  2,  1, 13,  2,  5, 26,  0, 12,  9, 22, 20,  9, 24,  2, 15,
#         21,  1, 20, 10, 15,  8,  9,  0, 15, 16, 21, 10,  4,  6,  1, 21,  9,  6,
#         20,  6,  1,  6, 25, 17, 19,  6, 20, 20, 10, 16, 15, 20,  1, 10, 15,  1,
#         21,  9,  6,  1, 21,  6, 25, 21,  1,  0, 10, 15,  7,  6, 19,  1, 21,  9,
#          6, 10, 19,  1, 14,  6,  2, 15, 10, 15,  8,  1,  7, 19, 16, 14,  1, 21,
#          9,  6,  1,  4, 16, 15, 21,  6, 25, 21,  1,  0, 14, 26,  1,  8, 19,  2,
#         15,  5, 14, 16, 21,  9,  6, 19,  1, 13, 10, 12,  6,  1,  6, 23,  6, 19,
#         26,  3, 16,  5, 26,  1, 20,  1,  8, 19,  2, 15,  5, 14, 16, 21,  9,  6,
#         19,  1, 24,  2, 20,  1,  2, 15,  1, 16, 13,  5,  1, 24, 16, 14,  2, 15,
#          1,  0, 20,  9,  6,  1,  9,  2,  5,  1,  3,  6,  6, 15,  1, 16, 13,  5,
#          1,  2, 15,  5,  1, 24, 19, 10, 15, 12, 13,  6,  5,  1,  7, 16, 19,  1,
#         21,  9,  6,  1, 21, 24,  6, 15, 21, 26,  1, 26,  6,  2, 19, 20,  1, 21,
#          9,  2, 21,  1, 10,  1,  9,  2,  5,  1, 12, 15, 16, 24, 15,  0,  9,  6,
#         19,  1, 17,  6, 16, 17, 13,  6,  1, 20,  2, 10,  5,  1, 21,  9,  2, 21,
#          1, 20,  9,  6,  1,  9,  2,  5,  1, 16, 15,  4,  6,  1,  3,  6,  6, 15,
#          1, 26, 16, 22, 15,  8,  1,  2, 15,  5,  1, 17, 19,  6, 21, 21, 26,  1,
#          2, 15,  5,  1,  9,  2,  5,  0,  6, 23,  6, 15,  1,  9,  2,  5,  1,  2,
#          1,  9, 22, 20,  3,  2, 15,  5,  1,  3, 22, 21,  1, 21,  9,  2, 21,  1,
#         24,  2, 20,  1,  9,  2, 19,  5,  1, 21, 16,  1,  3,  6, 13, 10,  6, 23,
#          6,  1, 14, 26,  1,  8, 19,  2, 15,  5,  7,  2, 21,  9,  6, 19,  1, 20,
#          0, 17, 16, 19, 21, 19,  2, 10, 21,  1,  9, 22, 15,  8,  1,  2,  3, 16,
#         23,  6,  1, 21,  9,  6,  1, 14,  2, 15, 21,  6, 13, 17, 10,  6,  4,  6,
#          1, 10, 15,  1, 21,  9,  6,  1,  5, 19,  2, 24, 10, 15,  8,  1, 19, 16,
#         16, 14,  1,  9,  6,  1, 24, 16, 19,  6,  1,  2,  0,  3, 10,  8,  1, 21,
#         22, 19,  3,  2, 15,  1,  2, 15,  5,  1, 13, 16, 16, 20,  6,  1,  7, 10,
#         21, 21, 10, 15,  8,  1,  4, 13, 16, 21,  9,  6, 20,  1,  9, 10, 20,  1,
#         13, 16, 15,  8,  1, 24,  9, 10, 21,  6,  1,  3,  6,  2, 19,  5,  1,  4,
#         16, 23,  6, 19,  6,  5,  1, 21,  9,  6])

# %% [markdown]
# ## Train / Validation Split
# `` Split dataset to detect overfitting ``
# - 90% training
# - 10% validation

# %%
# now split the data into train data and validation data
n=int(0.9*len(data))
train_data=data[:n]
val_data=data[n:]

# %%
block_size=18
train_data[:block_size+1]
# Out:
# tensor([21,  9,  6,  1, 17, 16, 19, 21, 19,  2, 10, 21,  1, 16,  7,  1,  2,  1,
#         13])

# %%
a=train_data[:block_size]
b=train_data[1:block_size+1]
for t in range(block_size):
       context=a[:t+1]
       target=b[t]
       print(f"Input:{context},target:{target}")
# Out:
# Input:tensor([21]),target:9
# Input:tensor([21,  9]),target:6
# Input:tensor([21,  9,  6]),target:1
# Input:tensor([21,  9,  6,  1]),target:17
# Input:tensor([21,  9,  6,  1, 17]),target:16
# Input:tensor([21,  9,  6,  1, 17, 16]),target:19
# Input:tensor([21,  9,  6,  1, 17, 16, 19]),target:21
# Input:tensor([21,  9,  6,  1, 17, 16, 19, 21]),target:19
# Input:tensor([21,  9,  6,  1, 17, 16, 19, 21, 19]),target:2
# Input:tensor([21,  9,  6,  1, 17, 16, 19, 21, 19,  2]),target:10
# Input:tensor([21,  9,  6,  1, 17, 16, 19, 21, 19,  2, 10]),target:21
# Input:tensor([21,  9,  6,  1, 17, 16, 19, 21, 19,  2, 10, 21]),target:1
# Input:tensor([21,  9,  6,  1, 17, 16, 19, 21, 19,  2, 10, 21,  1]),target:16
# Input:tensor([21,  9,  6,  1, 17, 16, 19, 21, 19,  2, 10, 21,  1, 16]),target:7
# Input:tensor([21,  9,  6,  1, 17, 16, 19, 21, 19,  2, 10, 21,  1, 16,  7]),target:1
# Input:tensor([21,  9,  6,  1, 17, 16, 19, 21, 19,  2, 10, 21,  1, 16,  7,  1]),target:2
# Input:tensor([21,  9,  6,  1, 17, 16, 19, 21, 19,  2, 10, 21,  1, 16,  7,  1,  2]),target:1
# Input:tensor([21,  9,  6,  1, 17, 16, 19, 21, 19,  2, 10, 21,  1, 16,  7,  1,  2,  1]),target:13

# %% [markdown]
# - Context and Target Example
# - Demonstrate next-token prediction

# %%
batch_size=4
block_size=18
torch.manual_seed(1337)
def get_batch(split):
       if split=='train':
              data=train_data
       else:
              data=val_data
       ix = torch.randint(len(data) - block_size, (batch_size,))
       x=torch.stack([data[i:i+block_size]for i in ix])
       y=torch.stack([data[i+1:i+block_size+1]for i in ix])
       return x,y

xb,yb=get_batch('train')
print('inputs:')
print(xb.shape)
print(xb)
print('targets:')
print(yb.shape)
print(yb)
print("--------------------------------------")

for b in range(batch_size):
       for t in range(block_size):
              context=xb[b,:t+1]
              target=yb[b,t]
              print(f"context:{context} and target:{target} ")
# Out:
# inputs:
# torch.Size([4, 18])
# tensor([[ 8,  6,  5,  1, 17, 16, 19, 21,  1,  9, 22, 13, 13,  1,  7,  2,  4, 10],
#         [22, 19,  6, 20,  1,  0, 16, 15,  6,  1,  5,  2, 26,  1, 10,  1,  2, 15],
#         [ 2,  4, 12,  1, 16, 15,  0,  5,  6,  4, 12,  1, 24, 10, 21,  9,  1, 21],
#         [22, 14, 17,  6,  5,  1, 21,  9,  6,  1, 20,  2,  8,  8, 10, 15,  8,  1]])
# targets:
# torch.Size([4, 18])
# tensor([[ 6,  5,  1, 17, 16, 19, 21,  1,  9, 22, 13, 13,  1,  7,  2,  4, 10, 15],
#         [19,  6, 20,  1,  0, 16, 15,  6,  1,  5,  2, 26,  1, 10,  1,  2, 15, 15],
#         [ 4, 12,  1, 16, 15,  0,  5,  6,  4, 12,  1, 24, 10, 21,  9,  1, 21,  9],
#         [14, 17,  6,  5,  1, 21,  9,  6,  1, 20,  2,  8,  8, 10, 15,  8,  1, 20]])
# --------------------------------------
# context:tensor([8]) and target:6
# context:tensor([8, 6]) and target:5
# context:tensor([8, 6, 5]) and target:1
# context:tensor([8, 6, 5, 1]) and target:17
# context:tensor([ 8,  6,  5,  1, 17]) and target:16
# context:tensor([ 8,  6,  5,  1, 17, 16]) and target:19
# context:tensor([ 8,  6,  5,  1, 17, 16, 19]) and target:21
# context:tensor([ 8,  6,  5,  1, 17, 16, 19, 21]) and target:1
# context:tensor([ 8,  6,  5,  1, 17, 16, 19, 21,  1]) and target:9
# context:tensor([ 8,  6,  5,  1, 17, 16, 19, 21,  1,  9]) and target:22
# context:tensor([ 8,  6,  5,  1, 17, 16, 19, 21,  1,  9, 22]) and target:13
# context:tensor([ 8,  6,  5,  1, 17, 16, 19, 21,  1,  9, 22, 13]) and target:13
# context:tensor([ 8,  6,  5,  1, 17, 16, 19, 21,  1,  9, 22, 13, 13]) and target:1
# context:tensor([ 8,  6,  5,  1, 17, 16, 19, 21,  1,  9, 22, 13, 13,  1]) and target:7
# context:tensor([ 8,  6,  5,  1, 17, 16, 19, 21,  1,  9, 22, 13, 13,  1,  7]) and target:2
# context:tensor([ 8,  6,  5,  1, 17, 16, 19, 21,  1,  9, 22, 13, 13,  1,  7,  2]) and target:4
# context:tensor([ 8,  6,  5,  1, 17, 16, 19, 21,  1,  9, 22, 13, 13,  1,  7,  2,  4]) and target:10
# context:tensor([ 8,  6,  5,  1, 17, 16, 19, 21,  1,  9, 22, 13, 13,  1,  7,  2,  4, 10]) and target:15
# context:tensor([22]) and target:19
# context:tensor([22, 19]) and target:6
# context:tensor([22, 19,  6]) and target:20
# context:tensor([22, 19,  6, 20]) and target:1
# context:tensor([22, 19,  6, 20,  1]) and target:0
# context:tensor([22, 19,  6, 20,  1,  0]) and target:16
# context:tensor([22, 19,  6, 20,  1,  0, 16]) and target:15
# context:tensor([22, 19,  6, 20,  1,  0, 16, 15]) and target:6
# context:tensor([22, 19,  6, 20,  1,  0, 16, 15,  6]) and target:1
# context:tensor([22, 19,  6, 20,  1,  0, 16, 15,  6,  1]) and target:5
# context:tensor([22, 19,  6, 20,  1,  0, 16, 15,  6,  1,  5]) and target:2
# context:tensor([22, 19,  6, 20,  1,  0, 16, 15,  6,  1,  5,  2]) and target:26
# context:tensor([22, 19,  6, 20,  1,  0, 16, 15,  6,  1,  5,  2, 26]) and target:1
# context:tensor([22, 19,  6, 20,  1,  0, 16, 15,  6,  1,  5,  2, 26,  1]) and target:10
# context:tensor([22, 19,  6, 20,  1,  0, 16, 15,  6,  1,  5,  2, 26,  1, 10]) and target:1
# context:tensor([22, 19,  6, 20,  1,  0, 16, 15,  6,  1,  5,  2, 26,  1, 10,  1]) and target:2
# context:tensor([22, 19,  6, 20,  1,  0, 16, 15,  6,  1,  5,  2, 26,  1, 10,  1,  2]) and target:15
# context:tensor([22, 19,  6, 20,  1,  0, 16, 15,  6,  1,  5,  2, 26,  1, 10,  1,  2, 15]) and target:15
# context:tensor([2]) and target:4
# context:tensor([2, 4]) and target:12
# context:tensor([ 2,  4, 12]) and target:1
# context:tensor([ 2,  4, 12,  1]) and target:16
# context:tensor([ 2,  4, 12,  1, 16]) and target:15
# context:tensor([ 2,  4, 12,  1, 16, 15]) and target:0
# context:tensor([ 2,  4, 12,  1, 16, 15,  0]) and target:5
# context:tensor([ 2,  4, 12,  1, 16, 15,  0,  5]) and target:6
# context:tensor([ 2,  4, 12,  1, 16, 15,  0,  5,  6]) and target:4
# context:tensor([ 2,  4, 12,  1, 16, 15,  0,  5,  6,  4]) and target:12
# context:tensor([ 2,  4, 12,  1, 16, 15,  0,  5,  6,  4, 12]) and target:1
# context:tensor([ 2,  4, 12,  1, 16, 15,  0,  5,  6,  4, 12,  1]) and target:24
# context:tensor([ 2,  4, 12,  1, 16, 15,  0,  5,  6,  4, 12,  1, 24]) and target:10
# context:tensor([ 2,  4, 12,  1, 16, 15,  0,  5,  6,  4, 12,  1, 24, 10]) and target:21
# context:tensor([ 2,  4, 12,  1, 16, 15,  0,  5,  6,  4, 12,  1, 24, 10, 21]) and target:9
# context:tensor([ 2,  4, 12,  1, 16, 15,  0,  5,  6,  4, 12,  1, 24, 10, 21,  9]) and target:1
# context:tensor([ 2,  4, 12,  1, 16, 15,  0,  5,  6,  4, 12,  1, 24, 10, 21,  9,  1]) and target:21
# context:tensor([ 2,  4, 12,  1, 16, 15,  0,  5,  6,  4, 12,  1, 24, 10, 21,  9,  1, 21]) and target:9
# context:tensor([22]) and target:14
# context:tensor([22, 14]) and target:17
# context:tensor([22, 14, 17]) and target:6
# context:tensor([22, 14, 17,  6]) and target:5
# context:tensor([22, 14, 17,  6,  5]) and target:1
# context:tensor([22, 14, 17,  6,  5,  1]) and target:21
# context:tensor([22, 14, 17,  6,  5,  1, 21]) and target:9
# context:tensor([22, 14, 17,  6,  5,  1, 21,  9]) and target:6
# context:tensor([22, 14, 17,  6,  5,  1, 21,  9,  6]) and target:1
# context:tensor([22, 14, 17,  6,  5,  1, 21,  9,  6,  1]) and target:20
# context:tensor([22, 14, 17,  6,  5,  1, 21,  9,  6,  1, 20]) and target:2
# context:tensor([22, 14, 17,  6,  5,  1, 21,  9,  6,  1, 20,  2]) and target:8
# context:tensor([22, 14, 17,  6,  5,  1, 21,  9,  6,  1, 20,  2,  8]) and target:8
# context:tensor([22, 14, 17,  6,  5,  1, 21,  9,  6,  1, 20,  2,  8,  8]) and target:10
# context:tensor([22, 14, 17,  6,  5,  1, 21,  9,  6,  1, 20,  2,  8,  8, 10]) and target:15
# context:tensor([22, 14, 17,  6,  5,  1, 21,  9,  6,  1, 20,  2,  8,  8, 10, 15]) and target:8
# context:tensor([22, 14, 17,  6,  5,  1, 21,  9,  6,  1, 20,  2,  8,  8, 10, 15,  8]) and target:1
# context:tensor([22, 14, 17,  6,  5,  1, 21,  9,  6,  1, 20,  2,  8,  8, 10, 15,  8,  1]) and target:20

# %% [markdown]
# ### Bigram Language Model
# - Predict next character based only on current character
# - Uses embedding lookup

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
torch.manual_seed(1337)

class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)

    def forward(self, idx, targets=None):

        # idx and targets are both (B,T) tensor of integers
        logits = self.token_embedding_table(idx) # (B,T,C)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

m = BigramLanguageModel(vocab_size2)
logits, loss = m(xb, yb)
print(logits.shape)
print(loss)

print(decode(m.generate(idx = torch.zeros((1, 1), dtype=torch.long), max_new_tokens=100)[0].tolist()))
# Out:
# torch.Size([72, 28])
# tensor(4.1525, grad_fn=<NllLossBackward0>)
#
# o gczsr
# iwsmm bjn rn xctpzdcyyhvnty
# n xawrhmsfrcywkkmrqkpdxjufpglkprzot
# gu
# u
# jnqectluy
# kzr
# qkpwoyr
# j
